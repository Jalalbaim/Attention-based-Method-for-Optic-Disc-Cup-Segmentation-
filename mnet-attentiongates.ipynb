# %% [markdown]
# # Training MNet

# %%
import numpy as np
from keras import backend as K
import scipy
from skimage.measure import label, regionprops
import os
from keras.preprocessing import image
import tensorflow as tf
from keras.optimizers import SGD
from keras.layers import (
    Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, BatchNormalization,
    Activation, Conv2DTranspose, Multiply, Add, AveragePooling2D, Average
)
from keras.models import Model
import random
from tensorflow.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## Utils

# %%
# Define helper functions
def mk_dir(dir_path):
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
    return dir_path

def return_list(data_path, data_type):
    file_list = [file for file in os.listdir(data_path) if file.lower().endswith(data_type)]
    print(str(len(file_list)))
    return file_list

def train_loader(data_list, data_path, mask_path, input_size):
    for lineIdx in range(len(data_list)):
        temp_txt = data_list[lineIdx]

        train_img = np.asarray(image.load_img(
            os.path.join(data_path, temp_txt),
            target_size=(input_size, input_size, 3))
        ).astype('float32')

        img_mask = np.asarray(image.load_img(
            os.path.join(mask_path, temp_txt),
            target_size=(input_size, input_size, 3))) / 255.0

        img_mask = img_mask.astype('float32')

        yield (train_img, (img_mask, img_mask, img_mask, img_mask, img_mask))


def tf_data_loader(data_list, data_path, mask_path, input_size):
    dataset = tf.data.Dataset.from_generator(
        lambda: train_loader(data_list, data_path, mask_path, input_size),
        output_signature=(
            tf.TensorSpec(shape=(input_size, input_size, 3), dtype=tf.float32),
            tuple([tf.TensorSpec(shape=(input_size, input_size, 3), dtype=tf.float32)] * 5)
        )
    )
    return dataset

# %%
# Training Settings
result_path = mk_dir('/kaggle/working/output_deep_model/')
pre_model_file = '/kaggle/input/deep-model/deep_model/Model_MNet_REFUGE.h5'
save_model_file = result_path + 'Model_MNet_REFUGE_v2.keras'

root_path = '/kaggle/input/training-data-polar/training_crop/'
train_data_path = root_path + 'data/'
train_mask_path = root_path + 'label/'

val_data_path = root_path + 'val_data/data/'
val_mask_path = root_path + 'val_data/label/'

train_list = return_list(train_data_path, '.png')
val_list = return_list(val_data_path, '.png')
# Out:
# 1400
# 300

# %% [markdown]
# ## Model MNet

# %%
from keras.layers import (
    Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, BatchNormalization,
    Activation, Conv2DTranspose, Multiply, Add, AveragePooling2D, Average
)
from keras.models import Model

def attention_gate(x, g, inter_channels):
    # x: Input feature map from the encoder (skip connection)
    # g: Gating signal from the decoder
    # inter_channels: Number of filters for intermediate computations

    theta_x = Conv2D(inter_channels, (2, 2), strides=(2, 2), padding='same')(x)
    phi_g = Conv2D(inter_channels, (1, 1), padding='same')(g)
    add = Add()([theta_x, phi_g])
    relu = Activation('relu')(add)
    psi = Conv2D(1, (1, 1), padding='same')(relu)
    sigmoid = Activation('sigmoid')(psi)
    upsampled = UpSampling2D(size=(2, 2), interpolation='bilinear')(sigmoid)
    attn_coefficients = Multiply()([x, upsampled])
    return attn_coefficients

def DeepModel(size_set=800):

    img_input = Input(shape=(size_set, size_set, 3))

    # Scaled inputs
    scale_img_2 = AveragePooling2D(pool_size=(2, 2))(img_input)
    scale_img_3 = AveragePooling2D(pool_size=(2, 2))(scale_img_2)
    scale_img_4 = AveragePooling2D(pool_size=(2, 2))(scale_img_3)

    # Block 1
    conv1 = Conv2D(32, (3, 3), padding='same', name='block1_conv1')(img_input)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    conv1 = Conv2D(32, (3, 3), padding='same', name='block1_conv2')(conv1)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    # Block 2
    input2 = Conv2D(64, (3, 3), padding='same', name='block2_input1')(scale_img_2)
    input2 = BatchNormalization()(input2)
    input2 = Activation('relu')(input2)
    input2 = concatenate([input2, pool1], axis=3)
    conv2 = Conv2D(64, (3, 3), padding='same', name='block2_conv1')(input2)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    conv2 = Conv2D(64, (3, 3), padding='same', name='block2_conv2')(conv2)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    # Block 3
    input3 = Conv2D(128, (3, 3), padding='same', name='block3_input1')(scale_img_3)
    input3 = BatchNormalization()(input3)
    input3 = Activation('relu')(input3)
    input3 = concatenate([input3, pool2], axis=3)
    conv3 = Conv2D(128, (3, 3), padding='same', name='block3_conv1')(input3)
    conv3 = BatchNormalization()(conv3)
    conv3 = Activation('relu')(conv3)
    conv3 = Conv2D(128, (3, 3), padding='same', name='block3_conv2')(conv3)
    conv3 = BatchNormalization()(conv3)
    conv3 = Activation('relu')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    # Block 4
    input4 = Conv2D(256, (3, 3), padding='same', name='block4_input1')(scale_img_4)
    input4 = BatchNormalization()(input4)
    input4 = Activation('relu')(input4)
    input4 = concatenate([input4, pool3], axis=3)
    conv4 = Conv2D(256, (3, 3), padding='same', name='block4_conv1')(input4)
    conv4 = BatchNormalization()(conv4)
    conv4 = Activation('relu')(conv4)
    conv4 = Conv2D(256, (3, 3), padding='same', name='block4_conv2')(conv4)
    conv4 = BatchNormalization()(conv4)
    conv4 = Activation('relu')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    # Bridge
    conv5 = Conv2D(512, (3, 3), padding='same', name='block5_conv1')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Activation('relu')(conv5)
    conv5 = Conv2D(512, (3, 3), padding='same', name='block5_conv2')(conv5)
    conv5 = BatchNormalization()(conv5)
    conv5 = Activation('relu')(conv5)

    # Decoder with Attention Gates
    # Up Block 6
    attn4 = attention_gate(conv4, conv5, inter_channels=256)
    up6 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same', name='block6_dconv')(conv5)
    up6 = concatenate([up6, attn4], axis=3)
    conv6 = Conv2D(256, (3, 3), padding='same', name='block6_conv1')(up6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Activation('relu')(conv6)
    conv6 = Conv2D(256, (3, 3), padding='same', name='block6_conv2')(conv6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Activation('relu')(conv6)

    # Up Block 7
    attn3 = attention_gate(conv3, conv6, inter_channels=128)
    up7 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same', name='block7_dconv')(conv6)
    up7 = concatenate([up7, attn3], axis=3)
    conv7 = Conv2D(128, (3, 3), padding='same', name='block7_conv1')(up7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Activation('relu')(conv7)
    conv7 = Conv2D(128, (3, 3), padding='same', name='block7_conv2')(conv7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Activation('relu')(conv7)

    # Up Block 8
    attn2 = attention_gate(conv2, conv7, inter_channels=64)
    up8 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same', name='block8_dconv')(conv7)
    up8 = concatenate([up8, attn2], axis=3)
    conv8 = Conv2D(64, (3, 3), padding='same', name='block8_conv1')(up8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Activation('relu')(conv8)
    conv8 = Conv2D(64, (3, 3), padding='same', name='block8_conv2')(conv8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Activation('relu')(conv8)

    # Up Block 9
    attn1 = attention_gate(conv1, conv8, inter_channels=32)
    up9 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same', name='block9_dconv')(conv8)
    up9 = concatenate([up9, attn1], axis=3)
    conv9 = Conv2D(32, (3, 3), padding='same', name='block9_conv1')(up9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Activation('relu')(conv9)
    conv9 = Conv2D(32, (3, 3), padding='same', name='block9_conv2')(conv9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Activation('relu')(conv9)

    # Side Outputs with 1 channel each
    side6 = UpSampling2D(size=(8, 8))(conv6)
    side7 = UpSampling2D(size=(4, 4))(conv7)
    side8 = UpSampling2D(size=(2, 2))(conv8)
    out6 = Conv2D(3, (1, 1), activation='softmax', name='side_63')(side6)
    out7 = Conv2D(3, (1, 1), activation='softmax', name='side_73')(side7)
    out8 = Conv2D(3, (1, 1), activation='softmax', name='side_83')(side8)
    out9 = Conv2D(3, (1, 1), activation='softmax', name='side_93')(conv9)
    
    # Final Output with name 'final_output'
    out10 = Average(name='final_output')([out6, out7, out8, out9])

    model = Model(inputs=[img_input], outputs=[out6, out7, out8, out9, out10])

    return model

# %%
# Define the Dice Loss function
def dice_loss(y_true, y_pred, smooth=1e-6):
    """
    Dice Loss for multiclass segmentation.
    """
    y_true_f = tf.reshape(y_true, [-1, tf.shape(y_true)[-1]])
    y_pred_f = tf.reshape(y_pred, [-1, tf.shape(y_pred)[-1]])
    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    denominator = tf.reduce_sum(y_true_f + y_pred_f, axis=0)
    dice_score = (2. * intersection + smooth) / (denominator + smooth)
    return 1 - tf.reduce_mean(dice_score)

# %% [markdown]
# # Training

# %%
# # Set the root and data paths
# root_path = '/kaggle/input/training-data-polar/training_crop/'
# train_data_path = os.path.join(root_path, 'data/')
# train_mask_path = os.path.join(root_path, 'label/')

# val_data_path = os.path.join(root_path, 'val_data/data/')
# val_mask_path = os.path.join(root_path, 'val_data/label/')

# # Define image dimensions
# IMAGE_SIZE = 800  # As per your model's input size

# # Function to load and preprocess images
# def load_image(path, target_size):
#     img = load_img(path, target_size=(target_size, target_size))
#     img = img_to_array(img)
#     img = img / 255.0  # Normalize to [0, 1]
#     return img

# # Function to load and preprocess masks
# def load_mask(path, target_size):
#     mask = load_img(path, target_size=(target_size, target_size), color_mode='grayscale')
#     mask = img_to_array(mask)
#     mask = mask / 255.0  # Normalize to [0, 1]
#     mask = np.round(mask)  # Ensure binary masks
#     return mask

# # Custom data generator
# class DataGenerator(Sequence):
#     def __init__(self, image_filenames, mask_filenames, image_dir, mask_dir, batch_size, target_size, shuffle=True):
#         self.image_filenames = image_filenames
#         self.mask_filenames = mask_filenames
#         self.image_dir = image_dir
#         self.mask_dir = mask_dir
#         self.batch_size = batch_size
#         self.target_size = target_size
#         self.shuffle = shuffle
#         self.on_epoch_end()
    
#     def __len__(self):
#         return int(np.ceil(len(self.image_filenames) / self.batch_size))
    
#     def __getitem__(self, index):
#         # Generate indexes of the batch
#         batch_indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        
#         # Find list of IDs
#         batch_image_filenames = [self.image_filenames[k] for k in batch_indexes]
#         batch_mask_filenames = [self.mask_filenames[k] for k in batch_indexes]
        
#         # Generate data
#         X, Y = self.__data_generation(batch_image_filenames, batch_mask_filenames)
        
#         return X, Y
    
#     def on_epoch_end(self):
#         self.indexes = np.arange(len(self.image_filenames))
#         if self.shuffle:
#             np.random.shuffle(self.indexes)
    
#     def __data_generation(self, batch_image_filenames, batch_mask_filenames):
#         X = np.empty((len(batch_image_filenames), self.target_size, self.target_size, 3), dtype=np.float32)
#         Y = np.empty((len(batch_mask_filenames), self.target_size, self.target_size, 1), dtype=np.float32)
        
#         for i, (img_name, mask_name) in enumerate(zip(batch_image_filenames, batch_mask_filenames)):
#             img_path = os.path.join(self.image_dir, img_name)
#             mask_path = os.path.join(self.mask_dir, mask_name)
            
#             # Load and preprocess images and masks
#             img = load_image(img_path, self.target_size)
#             mask = load_mask(mask_path, self.target_size)
            
#             X[i] = img
#             Y[i] = mask
        
#         # Prepare outputs as a dictionary mapping output names to targets
#         Y_multi = {
#             'side_63': Y,
#             'side_73': Y,
#             'side_83': Y,
#             'side_93': Y,
#             'final_output': Y
#         }
#         return X, Y_multi


# # Get the list of image and mask filenames for training
# train_image_files = sorted(os.listdir(train_data_path))
# train_mask_files = sorted(os.listdir(train_mask_path))

# # Get the list of image and mask filenames for validation
# val_image_files = sorted(os.listdir(val_data_path))
# val_mask_files = sorted(os.listdir(val_mask_path))

# # Create data generators
# batch_size = 4  # Adjust based on your GPU memory

# train_generator = DataGenerator(
#     train_image_files, train_mask_files,
#     train_data_path, train_mask_path,
#     batch_size=batch_size, target_size=IMAGE_SIZE, shuffle=True
# )

# val_generator = DataGenerator(
#     val_image_files, val_mask_files,
#     val_data_path, val_mask_path,
#     batch_size=batch_size, target_size=IMAGE_SIZE, shuffle=False
# )

# # Define the model
# model = DeepModel(size_set=IMAGE_SIZE)

# # Compile the model with dictionaries for losses and loss_weights
# losses = {
#     'side_63': 'binary_crossentropy',
#     'side_73': 'binary_crossentropy',
#     'side_83': 'binary_crossentropy',
#     'side_93': 'binary_crossentropy',
#     'final_output': 'binary_crossentropy'
# }

# loss_weights = {
#     'side_63': 0.1,
#     'side_73': 0.1,
#     'side_83': 0.1,
#     'side_93': 0.1,
#     'final_output': 0.6
# }

# def dice_coefficient(y_true, y_pred):
#     smooth = 1.  # Avoid division by zero
#     y_true_f = K.flatten(y_true)
#     y_pred_f = K.flatten(y_pred)
#     intersection = K.sum(y_true_f * y_pred_f)
#     return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# metrics = {
#     'side_63': ['accuracy'],
#     'side_73': ['accuracy'],
#     'side_83': ['accuracy'],
#     'side_93': ['accuracy'],
#     'final_output': ['accuracy']#, dice_coefficie
# }

# model.compile(
#     optimizer=Adam(learning_rate=1e-4),
#     loss=losses,
#     loss_weights=loss_weights,
#     metrics= metrics,
# )

# # Callbacks
# checkpoint = ModelCheckpoint(
#     '/kaggle/working/best_model.weights.h5',
#     monitor='val_loss',
#     verbose=1,
#     save_best_only=True,
#     mode='min',
#     save_weights_only=True
# )

# reduce_lr = ReduceLROnPlateau(
#     monitor='val_loss',
#     factor=0.5,
#     patience=5,
#     min_lr=1e-7,
#     verbose=1
# )

# early_stopping = EarlyStopping(
#     monitor='val_loss',
#     patience=10,
#     restore_best_weights=True
# )

# callbacks_list = [checkpoint, reduce_lr, early_stopping]

# # Train the model
# epochs = 50  # Adjust as needed
# print("Start training")
# model.fit(
#     train_generator,
#     validation_data=val_generator,
#     epochs=epochs,
#     callbacks=callbacks_list
# )

# %%
input_size = 224
batch_size = 8
epochs = 100  # Total number of epochs to train

train_list = return_list(train_data_path, '.png')
val_list = return_list(val_data_path, '.png')

# Create TensorFlow datasets
train_dataset = tf_data_loader(train_list, train_data_path, train_mask_path, input_size)
val_dataset = tf_data_loader(val_list, val_data_path, val_mask_path, input_size)

# Calculate steps per epoch
steps_per_epoch = len(train_list) // batch_size
validation_steps = len(val_list) // batch_size

# Prepare the datasets
train_dataset = (
    train_dataset
    .shuffle(buffer_size=len(train_list), reshuffle_each_iteration=True)
    .batch(batch_size)
    .repeat()  # Repeat indefinitely
    .prefetch(tf.data.AUTOTUNE)
)
val_dataset = (
    val_dataset
    .batch(batch_size)
    .repeat()
    .prefetch(tf.data.AUTOTUNE)
)


# Initialize the model
my_model = DeepModel(size_set=input_size)

# Define the optimizer
optimizer_setting = SGD(learning_rate=0.0001, momentum=0.9)

# Compile the model
my_model.compile(
    optimizer=optimizer_setting,
    loss=dice_loss,
    loss_weights=[0.1, 0.1, 0.1, 0.1, 0.6]
)

# Define callbacks for saving the best model and early stopping
checkpoint = ModelCheckpoint(
    filepath=save_model_file,
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1
)

# Train the model
history = my_model.fit(
    train_dataset,
    epochs=epochs,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_dataset,
    validation_steps=validation_steps,
    callbacks=[checkpoint, early_stopping],
    verbose=1
)
# Out:
# 1400
# 300
# Epoch 1/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.7632
# Epoch 1: val_loss improved from inf to 0.74284, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 66s 158ms/step - loss: 0.7632 - val_loss: 0.7428
# Epoch 2/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.7339
# Epoch 2: val_loss improved from 0.74284 to 0.71197, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 39s 147ms/step - loss: 0.7339 - val_loss: 0.7120
# Epoch 3/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.7111
# Epoch 3: val_loss improved from 0.71197 to 0.68722, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 39s 140ms/step - loss: 0.7110 - val_loss: 0.6872
# Epoch 4/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.6919
# Epoch 4: val_loss improved from 0.68722 to 0.67089, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 40s 136ms/step - loss: 0.6919 - val_loss: 0.6709
# Epoch 5/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.6752
# Epoch 5: val_loss improved from 0.67089 to 0.65713, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 38s 130ms/step - loss: 0.6752 - val_loss: 0.6571
# Epoch 6/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.6628
# Epoch 6: val_loss improved from 0.65713 to 0.64506, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 119ms/step - loss: 0.6627 - val_loss: 0.6451
# Epoch 7/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.6497
# Epoch 7: val_loss improved from 0.64506 to 0.63450, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 37s 119ms/step - loss: 0.6497 - val_loss: 0.6345
# Epoch 8/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.6386
# Epoch 8: val_loss improved from 0.63450 to 0.62465, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 34s 120ms/step - loss: 0.6385 - val_loss: 0.6246
# Epoch 9/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.6292
# Epoch 9: val_loss improved from 0.62465 to 0.61528, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 27s 119ms/step - loss: 0.6292 - val_loss: 0.6153
# Epoch 10/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.6206
# Epoch 10: val_loss improved from 0.61528 to 0.60687, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 118ms/step - loss: 0.6205 - val_loss: 0.6069
# Epoch 11/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.6121
# Epoch 11: val_loss improved from 0.60687 to 0.59887, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.6121 - val_loss: 0.5989
# Epoch 12/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.6036
# Epoch 12: val_loss improved from 0.59887 to 0.59230, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 120ms/step - loss: 0.6036 - val_loss: 0.5923
# Epoch 13/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5982
# Epoch 13: val_loss improved from 0.59230 to 0.58547, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5982 - val_loss: 0.5855
# Epoch 14/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5899
# Epoch 14: val_loss improved from 0.58547 to 0.57952, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5899 - val_loss: 0.5795
# Epoch 15/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5847
# Epoch 15: val_loss improved from 0.57952 to 0.57470, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5847 - val_loss: 0.5747
# Epoch 16/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5796
# Epoch 16: val_loss improved from 0.57470 to 0.57003, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5796 - val_loss: 0.5700
# Epoch 17/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5753
# Epoch 17: val_loss improved from 0.57003 to 0.56623, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5753 - val_loss: 0.5662
# Epoch 18/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5713
# Epoch 18: val_loss improved from 0.56623 to 0.56262, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5713 - val_loss: 0.5626
# Epoch 19/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5674
# Epoch 19: val_loss improved from 0.56262 to 0.55870, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5674 - val_loss: 0.5587
# Epoch 20/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5630
# Epoch 20: val_loss improved from 0.55870 to 0.55506, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 118ms/step - loss: 0.5630 - val_loss: 0.5551
# Epoch 21/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5603
# Epoch 21: val_loss improved from 0.55506 to 0.55299, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 120ms/step - loss: 0.5603 - val_loss: 0.5530
# Epoch 22/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5552
# Epoch 22: val_loss improved from 0.55299 to 0.54991, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5552 - val_loss: 0.5499
# Epoch 23/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5528
# Epoch 23: val_loss improved from 0.54991 to 0.54757, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5528 - val_loss: 0.5476
# Epoch 24/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5496
# Epoch 24: val_loss improved from 0.54757 to 0.54471, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5496 - val_loss: 0.5447
# Epoch 25/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5473
# Epoch 25: val_loss improved from 0.54471 to 0.54229, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 120ms/step - loss: 0.5473 - val_loss: 0.5423
# Epoch 26/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5445
# Epoch 26: val_loss improved from 0.54229 to 0.54014, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5445 - val_loss: 0.5401
# Epoch 27/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5459
# Epoch 27: val_loss improved from 0.54014 to 0.53790, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5459 - val_loss: 0.5379
# Epoch 28/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5396
# Epoch 28: val_loss improved from 0.53790 to 0.53665, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5396 - val_loss: 0.5366
# Epoch 29/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5380
# Epoch 29: val_loss improved from 0.53665 to 0.53515, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5380 - val_loss: 0.5351
# Epoch 30/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5381
# Epoch 30: val_loss improved from 0.53515 to 0.53342, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 119ms/step - loss: 0.5381 - val_loss: 0.5334
# Epoch 31/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5355
# Epoch 31: val_loss improved from 0.53342 to 0.53154, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5355 - val_loss: 0.5315
# Epoch 32/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5330
# Epoch 32: val_loss improved from 0.53154 to 0.53016, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5330 - val_loss: 0.5302
# Epoch 33/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5354
# Epoch 33: val_loss improved from 0.53016 to 0.52856, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 119ms/step - loss: 0.5354 - val_loss: 0.5286
# Epoch 34/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5315
# Epoch 34: val_loss improved from 0.52856 to 0.52737, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 22s 119ms/step - loss: 0.5315 - val_loss: 0.5274
# Epoch 35/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5312
# Epoch 35: val_loss improved from 0.52737 to 0.52588, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 120ms/step - loss: 0.5312 - val_loss: 0.5259
# Epoch 36/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5304
# Epoch 36: val_loss improved from 0.52588 to 0.52348, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 120ms/step - loss: 0.5304 - val_loss: 0.5235
# Epoch 37/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5253
# Epoch 37: val_loss improved from 0.52348 to 0.52311, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 119ms/step - loss: 0.5253 - val_loss: 0.5231
# Epoch 38/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5236
# Epoch 38: val_loss improved from 0.52311 to 0.52234, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 120ms/step - loss: 0.5237 - val_loss: 0.5223
# Epoch 39/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5261
# Epoch 39: val_loss improved from 0.52234 to 0.52050, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 120ms/step - loss: 0.5260 - val_loss: 0.5205
# Epoch 40/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5230
# Epoch 40: val_loss improved from 0.52050 to 0.51997, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 120ms/step - loss: 0.5230 - val_loss: 0.5200
# Epoch 41/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5210
# Epoch 41: val_loss improved from 0.51997 to 0.51851, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5210 - val_loss: 0.5185
# Epoch 42/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5201
# Epoch 42: val_loss improved from 0.51851 to 0.51785, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 119ms/step - loss: 0.5201 - val_loss: 0.5178
# Epoch 43/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5189
# Epoch 43: val_loss improved from 0.51785 to 0.51632, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 121ms/step - loss: 0.5189 - val_loss: 0.5163
# Epoch 44/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5171
# Epoch 44: val_loss improved from 0.51632 to 0.51577, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 120ms/step - loss: 0.5171 - val_loss: 0.5158
# Epoch 45/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5177
# Epoch 45: val_loss improved from 0.51577 to 0.51511, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 119ms/step - loss: 0.5177 - val_loss: 0.5151
# Epoch 46/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5145
# Epoch 46: val_loss improved from 0.51511 to 0.51370, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5145 - val_loss: 0.5137
# Epoch 47/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5153
# Epoch 47: val_loss improved from 0.51370 to 0.51273, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5153 - val_loss: 0.5127
# Epoch 48/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5140
# Epoch 48: val_loss improved from 0.51273 to 0.51181, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 119ms/step - loss: 0.5140 - val_loss: 0.5118
# Epoch 49/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5114
# Epoch 49: val_loss improved from 0.51181 to 0.51077, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5114 - val_loss: 0.5108
# Epoch 50/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5117
# Epoch 50: val_loss did not improve from 0.51077
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - loss: 0.5117 - val_loss: 0.5108
# Epoch 51/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5122
# Epoch 51: val_loss improved from 0.51077 to 0.50908, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 120ms/step - loss: 0.5121 - val_loss: 0.5091
# Epoch 52/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5103
# Epoch 52: val_loss improved from 0.50908 to 0.50761, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5103 - val_loss: 0.5076
# Epoch 53/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5085
# Epoch 53: val_loss improved from 0.50761 to 0.50761, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 120ms/step - loss: 0.5085 - val_loss: 0.5076
# Epoch 54/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5073
# Epoch 54: val_loss improved from 0.50761 to 0.50743, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 120ms/step - loss: 0.5073 - val_loss: 0.5074
# Epoch 55/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5080
# Epoch 55: val_loss improved from 0.50743 to 0.50684, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 119ms/step - loss: 0.5080 - val_loss: 0.5068
# Epoch 56/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5060
# Epoch 56: val_loss improved from 0.50684 to 0.50611, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5060 - val_loss: 0.5061
# Epoch 57/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5065
# Epoch 57: val_loss improved from 0.50611 to 0.50486, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 119ms/step - loss: 0.5065 - val_loss: 0.5049
# Epoch 58/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5050
# Epoch 58: val_loss improved from 0.50486 to 0.50438, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5050 - val_loss: 0.5044
# Epoch 59/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5061
# Epoch 59: val_loss did not improve from 0.50438
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 115ms/step - loss: 0.5061 - val_loss: 0.5044
# Epoch 60/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5022
# Epoch 60: val_loss improved from 0.50438 to 0.50379, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5022 - val_loss: 0.5038
# Epoch 61/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5043
# Epoch 61: val_loss improved from 0.50379 to 0.50306, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5043 - val_loss: 0.5031
# Epoch 62/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5036
# Epoch 62: val_loss improved from 0.50306 to 0.50205, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5036 - val_loss: 0.5021
# Epoch 63/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5030
# Epoch 63: val_loss improved from 0.50205 to 0.50167, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 121ms/step - loss: 0.5030 - val_loss: 0.5017
# Epoch 64/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5004
# Epoch 64: val_loss improved from 0.50167 to 0.50135, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5004 - val_loss: 0.5013
# Epoch 65/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.5019
# Epoch 65: val_loss improved from 0.50135 to 0.50057, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.5019 - val_loss: 0.5006
# Epoch 66/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5008
# Epoch 66: val_loss did not improve from 0.50057
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - loss: 0.5008 - val_loss: 0.5010
# Epoch 67/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5001
# Epoch 67: val_loss improved from 0.50057 to 0.50028, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 25s 120ms/step - loss: 0.5001 - val_loss: 0.5003
# Epoch 68/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4983
# Epoch 68: val_loss improved from 0.50028 to 0.49993, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 120ms/step - loss: 0.4983 - val_loss: 0.4999
# Epoch 69/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.4990
# Epoch 69: val_loss improved from 0.49993 to 0.49944, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 120ms/step - loss: 0.4990 - val_loss: 0.4994
# Epoch 70/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4971
# Epoch 70: val_loss improved from 0.49944 to 0.49896, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.4971 - val_loss: 0.4990
# Epoch 71/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4983
# Epoch 71: val_loss improved from 0.49896 to 0.49887, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 119ms/step - loss: 0.4983 - val_loss: 0.4989
# Epoch 72/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.4963
# Epoch 72: val_loss improved from 0.49887 to 0.49824, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.4963 - val_loss: 0.4982
# Epoch 73/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4968
# Epoch 73: val_loss improved from 0.49824 to 0.49797, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 120ms/step - loss: 0.4968 - val_loss: 0.4980
# Epoch 74/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4954
# Epoch 74: val_loss improved from 0.49797 to 0.49627, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 120ms/step - loss: 0.4954 - val_loss: 0.4963
# Epoch 75/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4943
# Epoch 75: val_loss did not improve from 0.49627
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 116ms/step - loss: 0.4943 - val_loss: 0.4970
# Epoch 76/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.4945
# Epoch 76: val_loss did not improve from 0.49627
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 115ms/step - loss: 0.4945 - val_loss: 0.4970
# Epoch 77/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4950
# Epoch 77: val_loss improved from 0.49627 to 0.49610, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.4950 - val_loss: 0.4961
# Epoch 78/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4967
# Epoch 78: val_loss did not improve from 0.49610
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - loss: 0.4967 - val_loss: 0.4961
# Epoch 79/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.4946
# Epoch 79: val_loss improved from 0.49610 to 0.49564, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 119ms/step - loss: 0.4946 - val_loss: 0.4956
# Epoch 80/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.4948
# Epoch 80: val_loss did not improve from 0.49564
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - loss: 0.4948 - val_loss: 0.4958
# Epoch 81/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4927
# Epoch 81: val_loss improved from 0.49564 to 0.49475, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 119ms/step - loss: 0.4927 - val_loss: 0.4948
# Epoch 82/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4935
# Epoch 82: val_loss did not improve from 0.49475
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 22s 116ms/step - loss: 0.4935 - val_loss: 0.4948
# Epoch 83/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.4922
# Epoch 83: val_loss did not improve from 0.49475
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 115ms/step - loss: 0.4922 - val_loss: 0.4950
# Epoch 84/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4917
# Epoch 84: val_loss improved from 0.49475 to 0.49407, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.4917 - val_loss: 0.4941
# Epoch 85/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.4915
# Epoch 85: val_loss improved from 0.49407 to 0.49373, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.4915 - val_loss: 0.4937
# Epoch 86/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.4909
# Epoch 86: val_loss improved from 0.49373 to 0.49341, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.4910 - val_loss: 0.4934
# Epoch 87/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.4914
# Epoch 87: val_loss improved from 0.49341 to 0.49297, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.4914 - val_loss: 0.4930
# Epoch 88/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4902
# Epoch 88: val_loss did not improve from 0.49297
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 115ms/step - loss: 0.4902 - val_loss: 0.4934
# Epoch 89/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.4910
# Epoch 89: val_loss improved from 0.49297 to 0.49215, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.4910 - val_loss: 0.4921
# Epoch 90/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.4908
# Epoch 90: val_loss improved from 0.49215 to 0.49107, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.4908 - val_loss: 0.4911
# Epoch 91/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4893
# Epoch 91: val_loss did not improve from 0.49107
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - loss: 0.4893 - val_loss: 0.4919
# Epoch 92/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.4891
# Epoch 92: val_loss did not improve from 0.49107
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 115ms/step - loss: 0.4891 - val_loss: 0.4921
# Epoch 93/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.4904
# Epoch 93: val_loss did not improve from 0.49107
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - loss: 0.4904 - val_loss: 0.4919
# Epoch 94/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.4903
# Epoch 94: val_loss did not improve from 0.49107
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 115ms/step - loss: 0.4903 - val_loss: 0.4914
# Epoch 95/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4892
# Epoch 95: val_loss improved from 0.49107 to 0.49084, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.4892 - val_loss: 0.4908
# Epoch 96/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4891
# Epoch 96: val_loss improved from 0.49084 to 0.49058, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.4891 - val_loss: 0.4906
# Epoch 97/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.4883
# Epoch 97: val_loss did not improve from 0.49058
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 116ms/step - loss: 0.4883 - val_loss: 0.4909
# Epoch 98/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.4880
# Epoch 98: val_loss improved from 0.49058 to 0.49055, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 24s 119ms/step - loss: 0.4880 - val_loss: 0.4906
# Epoch 99/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.4885
# Epoch 99: val_loss improved from 0.49055 to 0.49040, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.4885 - val_loss: 0.4904
# Epoch 100/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.4872
# Epoch 100: val_loss improved from 0.49040 to 0.48956, saving model to /kaggle/working/output_deep_model/Model_MNet_REFUGE_v2.keras
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.4872 - val_loss: 0.4896

# %% [markdown]
# ## Validation try

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
# Function to load a single image and mask
def load_single_image(img_path, mask_path, target_size):
    # Load and preprocess the image
    img = np.asarray(image.load_img(
        img_path,
        target_size=(target_size, target_size, 3))
    ).astype('float32')
    
    # Load and preprocess the mask
    img_mask = image.load_img(
        mask_path,
        target_size=(target_size, target_size),
        color_mode='grayscale')
    
    img_mask = np.asarray(img_mask).astype('int32')
    
    return img, img_mask

# Select a sample from the validation set
sample_index = 0
sample_img_name = val_list[sample_index]
sample_mask_name = val_list[sample_index]  # Assuming mask filenames are the same as image filenames

sample_img_path = os.path.join(val_data_path, sample_img_name)
sample_mask_path = os.path.join(val_mask_path, sample_mask_name)

# Load the image and mask
input_size = 224  # Ensure this matches your model's expected input size
img, mask = load_single_image(sample_img_path, sample_mask_path, input_size)
img_input = np.expand_dims(img, axis=0)  # Add batch dimension

# Predict
predictions = my_model.predict(img_input)
final_output = predictions[-1][0]  # Extract the first sample from the batch

# Since the model outputs softmax probabilities over 3 classes, take the argmax to get predicted class labels
predicted_mask = np.argmax(final_output, axis=-1)

# Visualization
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(img/255.0)
plt.title('Input Image')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(mask, cmap='gray')
plt.title('Ground Truth Mask')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(predicted_mask)
plt.title('Predicted Mask')
plt.axis('off')

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
